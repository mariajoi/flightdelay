# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Dataset import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('random_data.csv')
df.head(5)
# Out:
#    Unnamed: 0  Month  DayofMonth  DayOfWeek  FlightDate Operating_Airline   \
# 0      292930      1          10          1  2022-01-10                 9E
# 1      352048      1          30          7  2022-01-30                 AA
# 2      238647      1           7          5  2022-01-07                 WN
# 3      274529      1          30          7  2022-01-30                 YX
# 4       27136      1          19          3  2022-01-19                 DL
#
#   Tail_Number  Flight_Number_Operating_Airline  OriginAirportID Origin  ...  \
# 0      N8783E                             5083            15323    TRI  ...
# 1      N9008U                             2115            11066    CMH  ...
# 2      N263WN                             6187            10423    AUS  ...
# 3         NaN                             4578            11995    GSO  ...
# 4      N816DN                             1508            14524    RIC  ...
#
#   CRSElapsedTime ActualElapsedTime  AirTime Distance DistanceGroup  \
# 0           74.0              56.0     40.0    227.0             1
# 1          178.0             198.0    148.0    990.0             4
# 2          100.0              89.0     70.0    528.0             3
# 3          108.0               NaN      NaN    461.0             2
# 4          106.0              98.0     75.0    481.0             2
#
#   CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 0          NaN           NaN       NaN            NaN                NaN
# 1          0.0           0.0      18.0            0.0                0.0
# 2         62.0           0.0       0.0            0.0                0.0
# 3          NaN           NaN       NaN            NaN                NaN
# 4          NaN           NaN       NaN            NaN                NaN
#
# [5 rows x 43 columns]

# %%
df.describe()
# Out:
#           Unnamed: 0         Month     DayofMonth      DayOfWeek  \
# count  240000.000000  240000.00000  240000.000000  240000.000000
# mean   291912.668867       6.50000      15.713517       3.977608
# std    169353.737497       3.45206       8.788796       1.998053
# min         2.000000       1.00000       1.000000       1.000000
# 25%    145712.750000       3.75000       8.000000       2.000000
# 50%    291072.000000       6.50000      16.000000       4.000000
# 75%    437335.500000       9.25000      23.000000       6.000000
# max    618774.000000      12.00000      31.000000       7.000000
#
#        Flight_Number_Operating_Airline  OriginAirportID  DestAirportID  \
# count                    240000.000000    240000.000000  240000.000000
# mean                       2501.379054     12658.762862   12656.874342
# std                        1713.802730      1523.392769    1523.667682
# min                           1.000000     10135.000000   10135.000000
# 25%                        1086.000000     11292.000000   11292.000000
# 50%                        2181.000000     12889.000000   12889.000000
# 75%                        3755.000000     14027.000000   14025.000000
# max                        9678.000000     16869.000000   16869.000000
#
#           CRSDepTime        DepTime       DepDelay  ...  CRSElapsedTime  \
# count  240000.000000  233610.000000  233608.000000  ...   240000.000000
# mean     1328.386575    1332.854694      12.415782  ...      140.922792
# std       489.917722     504.020231      52.460358  ...       71.563994
# min         1.000000       1.000000     -62.000000  ...        1.000000
# 25%       914.000000     916.000000      -5.000000  ...       89.000000
# 50%      1320.000000    1323.000000      -2.000000  ...      123.000000
# 75%      1733.000000    1742.000000      10.000000  ...      171.000000
# max      2359.000000    2400.000000    1709.000000  ...      685.000000
#
#        ActualElapsedTime        AirTime       Distance  DistanceGroup  \
# count      232941.000000  232941.000000  240000.000000  240000.000000
# mean          135.484728     110.570346     796.453658       3.656804
# std            71.602453      69.687283     590.931159       2.320099
# min            17.000000       9.000000      31.000000       1.000000
# 25%            83.000000      60.000000     366.000000       2.000000
# 50%           118.000000      93.000000     641.000000       3.000000
# 75%           166.000000     140.000000    1030.250000       5.000000
# max           705.000000     676.000000    5095.000000      11.000000
#
#        CarrierDelay  WeatherDelay      NASDelay  SecurityDelay  \
# count  48452.000000  48452.000000  48452.000000   48452.000000
# mean      26.707030      3.898043     11.489123       0.165669
# std       75.080206     31.300770     29.195426       5.786889
# min        0.000000      0.000000      0.000000       0.000000
# 25%        0.000000      0.000000      0.000000       0.000000
# 50%        7.000000      0.000000      0.000000       0.000000
# 75%       25.000000      0.000000     15.000000       0.000000
# max     1709.000000   1287.000000   1107.000000    1091.000000
#
#        LateAircraftDelay
# count       48452.000000
# mean           25.596756
# std            55.363433
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%            30.000000
# max          1653.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Percentage of delayed and cancelled flights, avg. delay per carrier

# %%
df_time = df[['Month', 'ArrDelayMinutes', 'ArrDel15']].copy()
df_carr = df[['Operating_Airline ', 'ArrDelayMinutes', 'ArrDel15', 'Flight_Number_Operating_Airline', 'Cancelled']].copy()
carrier_groups = df_carr.groupby('Operating_Airline ')
carr_metrics = carrier_groups.agg({'ArrDelayMinutes': 'sum', 'ArrDel15': 'sum', 'Operating_Airline ': 'count', 'Cancelled': 'sum'})

# %%
# Percentage of delayed flights
carr_metrics['Percentage_Delayed'] = carr_metrics['ArrDel15'] / carr_metrics['Operating_Airline '] * 100

# Average delay time
carr_metrics['Average_Delay_Time'] = carr_metrics['ArrDelayMinutes'] / carr_metrics['ArrDel15']

# Percentage cancelled flights
carr_metrics['Percentage_Cancelled'] = carr_metrics['Cancelled'] / carr_metrics['Operating_Airline '] * 100

# Ranked df (based on percentage of delayed flights)
carrier_ranking = carr_metrics.sort_values(by='Percentage_Delayed', ascending=False)
carrier_ranking = pd.DataFrame(carrier_ranking)

display(carrier_ranking)
# Out:
#                     ArrDelayMinutes  ArrDel15  Operating_Airline   Cancelled  \
# Operating_Airline
# G4                          94952.0    1302.0                4003      155.0
# B6                         238303.0    2910.0                9268      338.0
# F9                         125727.0    1633.0                5330      135.0
# NK                         143765.0    1964.0                8012      246.0
# HA                          27847.0     565.0                2446       22.0
# WN                         582089.0   10374.0               45054     1477.0
# G7                          37969.0     416.0                1879      107.0
# AA                         519710.0    6544.0               29900      880.0
# AS                          85318.0    1541.0                7738      209.0
# YX                         158224.0    2065.0               10816      519.0
# C5                          44096.0     491.0                2611       67.0
# YV                          75158.0     731.0                3893      142.0
# OH                          99462.0    1335.0                7292      222.0
# UA                         302725.0    3904.0               21365      402.0
# QX                          30681.0     515.0                2930       49.0
# ZW                          33063.0     366.0                2203       79.0
# MQ                          91698.0    1442.0                8792      178.0
# OO                         356854.0    4058.0               25093      450.0
# 9E                          98455.0    1216.0                7894      269.0
# DL                         354428.0    4698.0               30648      519.0
# PT                          32401.0     382.0                2833       51.0
#
#                     Percentage_Delayed  Average_Delay_Time  \
# Operating_Airline
# G4                           32.525606           72.927803
# B6                           31.398360           81.891065
# F9                           30.637899           76.991427
# NK                           24.513230           73.200102
# HA                           23.098937           49.286726
# WN                           23.025702           56.110372
# G7                           22.139436           91.271635
# AA                           21.886288           79.417787
# AS                           19.914707           55.365347
# YX                           19.092086           76.621792
# C5                           18.805056           89.808554
# YV                           18.777293          102.815321
# OH                           18.307735           74.503371
# UA                           18.272876           77.542264
# QX                           17.576792           59.574757
# ZW                           16.613709           90.336066
# MQ                           16.401274           63.590846
# OO                           16.171841           87.938393
# 9E                           15.404104           80.966283
# DL                           15.328896           75.442316
# PT                           13.483939           84.819372
#
#                     Percentage_Cancelled
# Operating_Airline
# G4                              3.872096
# B6                              3.646957
# F9                              2.532833
# NK                              3.070394
# HA                              0.899428
# WN                              3.278288
# G7                              5.694518
# AA                              2.943144
# AS                              2.700956
# YX                              4.798447
# C5                              2.566067
# YV                              3.647573
# OH                              3.044432
# UA                              1.881582
# QX                              1.672355
# ZW                              3.586019
# MQ                              2.024568
# OO                              1.793329
# 9E                              3.407651
# DL                              1.693422
# PT                              1.800212

# %% [markdown]
# ### Average Delay Time per Carrier plotted

# %%
plt.figure(figsize = (12,8))

sns.barplot(x=carrier_ranking.index, y=carrier_ranking['Average_Delay_Time'])
plt.xticks(rotation = 90)

# Horizontal line (overall average)
mean_avg_delay_time = carrier_ranking['Average_Delay_Time'].mean()
plt.axhline(y=mean_avg_delay_time, color='red', linestyle='--', label=f'Mean: {mean_avg_delay_time:.2f}')

plt.title('Average Delay Time depending on the carrier', fontweight = 'bold')
plt.ylabel('Average Delay Time', fontweight = 'bold')
plt.xlabel('Carrier', fontweight = 'bold')

plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

print('Overall Average Delay Time:', carrier_ranking['Average_Delay_Time'].mean().round(2))
# Out:
# Overall Average Delay Time: 76.21

# %% [markdown]
# ### Airports with highest delays (%)

# %%
(df.query('ArrDelay >= 60' or 'Cancelled > 0').DistanceGroup.value_counts(normalize=True).head(10)*100).round(2).reset_index().rename(columns={'proportion': 'percent'})
# Out:
#    DistanceGroup  percent
# 0              2    21.71
# 1              3    19.68
# 2              4    17.11
# 3              5    13.58
# 4              1    12.35
# 5              6     4.42
# 6              7     4.20
# 7             10     2.28
# 8             11     1.81
# 9              8     1.62

# %% [markdown]
# ### Departure vs. Arrival Delay

# %%
plt.figure(figsize=(7, 7))
plt.scatter(df.ArrDelay, df.DepDelay, c='yellow', alpha=.2)
plt.grid()
plt.xlim(-60, 600)
plt.ylim(-60, 600)
plt.xticks(np.arange(0,601, 60), labels=np.arange(0,601,60)//60)
plt.yticks(np.arange(0,601, 60), labels=np.arange(0,601,60)//60)
plt.xlabel('Departure delay in hours')
plt.ylabel('Arrival delay in hours')
plt.title('Scatterplot of Departure/Arrival Delays', fontsize=15)
plt.show()

# %% [markdown]
# ### Causes for delay

# %%
df_delay = df[['CarrierDelay','WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']].copy()
df_delay.head(5)
# Out:
#    CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 0           NaN           NaN       NaN            NaN                NaN
# 1           0.0           0.0      18.0            0.0                0.0
# 2          62.0           0.0       0.0            0.0                0.0
# 3           NaN           NaN       NaN            NaN                NaN
# 4           NaN           NaN       NaN            NaN                NaN

# %%
delay_reasons = df_delay.sum() # gives the delay in minutes

# Renaming
delay_reasons = delay_reasons.rename(index={
    'CarrierDelay': 'Carrier',
    'WeatherDelay': 'Weather',
    'NASDelay': 'National Aviation System',
    'SecurityDelay': 'Security',
    'LateAircraftDelay': 'Late Aircraft'
})

# %%
# Piechart
labels = delay_reasons.index
sizes = delay_reasons
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightblue']

plt.pie(sizes, labels = labels, colors = colors,  autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Distribution of Delay Reasons', fontweight='bold')
plt.axis('equal')

plt.tight_layout()
plt.show()

display(delay_reasons.sort_values(ascending = False).astype(int))
# Out:
# Carrier                     1294009
# Late Aircraft               1240214
# National Aviation System     556671
# Weather                      188868
# Security                       8027
# dtype: int64

# %% [markdown]
# ### Airline Identifier

# %%
airline_codes = pd.read_csv('L_UNIQUE_CARRIERS.csv')

# # define the majors codes from the top hits results
# majors_codes = ["WN", "DL", "AA", "OO", "UA", "YX", "B6", "MQ", "NK", "9E", "AS", "OH", "YV", "HA", "F9", "G4", "QX", "PT", "C5", "ZW", "G7"]

# filter, update, then view the list
major_airlines = airline_codes[airline_codes['Code'].isin(df['Operating_Airline '])]
major_airlines
# Out:
#      Code                              Description
# 170    9E                        Endeavor Air Inc.
# 187    AA                   American Airlines Inc.
# 318    AS                     Alaska Airlines Inc.
# 360    B6                          JetBlue Airways
# 424    C5            CommuteAir LLC dba CommuteAir
# 550    DL                     Delta Air Lines Inc.
# 635    F9                   Frontier Airlines Inc.
# 682    G4                            Allegiant Air
# 683    G7  GoJet Airlines LLC d/b/a United Express
# 751    HA                   Hawaiian Airlines Inc.
# 1015   MQ                                Envoy Air
# 1078   NK                         Spirit Air Lines
# 1114   OH                        PSA Airlines Inc.
# 1129   OO                    SkyWest Airlines Inc.
# 1215   PT                        Piedmont Airlines
# 1249   QX                              Horizon Air
# 1505   UA                    United Air Lines Inc.
# 1607   WN                   Southwest Airlines Co.
# 1697   YV                       Mesa Airlines Inc.
# 1698   YX                         Republic Airline
# 1724   ZW              Air Wisconsin Airlines Corp

# %% [markdown]
# ### Delay per month / incl. categories

# %%
df_month = df.groupby("DayOfWeek")["DelayGroup"].value_counts(normalize=True).unstack() * 100
col_order = ["OnTime_Early", "Small_Delay", "Medium_Delay", "Large_Delay"]
df_month[col_order].style.background_gradient(cmap="Purples")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_month = df.groupby("DayOfWeek")["DelayGroup"].value_counts(normalize=True).unstack() * 100
#       2 col_order = ["OnTime_Early", "Small_Delay", "Medium_Delay", "Large_Delay"]
#       3 df_month[col_order].style.background_gradient(cmap="Purples")
#
# File ~/.pyenv/versions/3.10.6/envs/flightdelay/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1964, in DataFrameGroupBy.__getitem__(self, key)
#    1957 if isinstance(key, tuple) and len(key) > 1:
#    1958     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1959     # valid syntax, so don't raise
#    1960     raise ValueError(
#    1961         "Cannot subset columns with a tuple with more than one element. "
#    1962         "Use a list instead."
#    1963     )
# -> 1964 return super().__getitem__(key)
#
# File ~/.pyenv/versions/3.10.6/envs/flightdelay/lib/python3.10/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: DelayGroup'

# %% [markdown]
# ### Flight Delay Distribution

# %%
df.query("ArrDelayMinutes > 1 and ArrDelayMinutes < 120")["ArrDelayMinutes"].plot(
    kind="hist", bins=30, title="Distribution of Flight Delays <= 120 Min"
)
plt.show()

# %% [markdown]
# ### Delay Groups

# %%
df["DelayGroup"] = None
df.loc[df["DepDelayMinutes"] == 0, "DelayGroup"] = "OnTime_Early"
df.loc[
    (df["DepDelayMinutes"] > 0) & (df["DepDelayMinutes"] <= 15), "DelayGroup"
] = "Small_Delay"
df.loc[
    (df["DepDelayMinutes"] > 15) & (df["DepDelayMinutes"] <= 45), "DelayGroup"
] = "Medium_Delay"
df.loc[df["DepDelayMinutes"] > 45, "DelayGroup"] = "Large_Delay"
df.loc[df["Cancelled"] == 1, "DelayGroup"] = "Cancelled"

# %%
df["DelayGroup"].value_counts(ascending=True).plot(
    kind="barh", figsize=(10, 5), title="Flight Results (2022)"
)
plt.show()

# %% [markdown]
# ### Cancelled Flights

# %%
print(df['Cancelled'].value_counts())
print('Percent Cancelled :', round(sum(df['Cancelled'] == True) / len(df['Cancelled']) * 100, 2), '% of all flights')
# Out:
# Cancelled
# 0.0    233484
# 1.0      6516
# Name: count, dtype: int64
# Percent Cancelled : 2.71 % of all flights

# %% [markdown]
# ### Various types of delays per airline

# %%
plt.figure(figsize=(20,12))
airline_order = df['Operating_Airline '].value_counts().index.tolist()
sns.countplot(data=df, y='Operating_Airline ', order=airline_order, hue='DelayGroup', dodge=False)
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
df_heatmap = df[['Month', 'DayofMonth', 'DayOfWeek', 'Origin', 'Dest', 'DepDelayMinutes', 'ArrDelayMinutes','Cancelled',  'AirTime', 'Distance', 'DistanceGroup']]

df_heatmap.shape
# Out:
# (240000, 11)

# %%
heatmap = sns.heatmap(df_heatmap.corr(), vmin=-1, vmax=1, annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 heatmap = sns.heatmap(df_heatmap.corr(), vmin=-1, vmax=1, annot=True)
#
# File ~/.pyenv/versions/3.10.6/envs/flightdelay/lib/python3.10/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.pyenv/versions/3.10.6/envs/flightdelay/lib/python3.10/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/.pyenv/versions/3.10.6/envs/flightdelay/lib/python3.10/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/.pyenv/versions/3.10.6/envs/flightdelay/lib/python3.10/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'TRI'

# %% [markdown]
# ## Per destination/arrival analysis

# %%
df.Origin.value_counts()
# Out:
# Origin
# ATL    10971
# ORD    10222
# DFW     9479
# DEN     9432
# CLT     7407
#        ...
# SMX        3
# PPG        3
# BKG        2
# OWB        1
# OGD        1
# Name: count, Length: 372, dtype: int64

# %% [markdown]
# ### Origins with highest delays (%)

# %%
(df.query('ArrDelay >= 60' or 'Cancelled > 0').Origin.value_counts(normalize=True).head(20)*100).round(2).reset_index().rename(columns={'proportion': 'percent'})
# Out:
#    Origin  percent
# 0     DFW     4.74
# 1     DEN     4.43
# 2     ORD     4.23
# 3     ATL     3.44
# 4     LGA     3.42
# 5     MCO     3.40
# 6     EWR     3.24
# 7     CLT     3.17
# 8     JFK     2.63
# 9     DCA     2.53
# 10    LAS     2.51
# 11    BOS     2.31
# 12    PHX     2.09
# 13    MIA     1.96
# 14    LAX     1.96
# 15    IAH     1.93
# 16    FLL     1.73
# 17    SEA     1.68
# 18    DTW     1.61
# 19    SFO     1.47

# %% [markdown]
# ### Origins with lowest delays (%)

# %%
(df.query('ArrDelay <= 0').Origin.value_counts(normalize=True).head(20)*100).round(2).reset_index().rename(columns={'proportion': 'percent'})
# Out:
#    Origin  percent
# 0     ATL     4.81
# 1     ORD     4.43
# 2     DFW     3.67
# 3     DEN     3.47
# 4     CLT     3.12
# 5     LAX     2.95
# 6     LGA     2.37
# 7     SEA     2.36
# 8     IAH     2.28
# 9     PHX     2.26
# 10    SFO     2.15
# 11    LAS     2.14
# 12    DTW     2.05
# 13    DCA     2.05
# 14    BOS     2.01
# 15    EWR     1.91
# 16    MSP     1.88
# 17    MCO     1.81
# 18    JFK     1.80
# 19    SLC     1.72

# %% [markdown]
# ### Dest with highest delays (%)

# %%
(df.query('ArrDelay >= 30' or 'Cancelled > 0').Dest.value_counts(normalize=True).head(20)*100).round(2).reset_index().rename(columns={'proportion': 'percent'})
# Out:
#    Dest  percent
# 0   DFW     4.08
# 1   ORD     3.90
# 2   DEN     3.70
# 3   ATL     3.66
# 4   MCO     3.08
# 5   EWR     3.00
# 6   LGA     2.99
# 7   LAS     2.95
# 8   JFK     2.62
# 9   BOS     2.45
# 10  CLT     2.45
# 11  LAX     2.36
# 12  DCA     2.22
# 13  PHX     2.11
# 14  IAH     1.85
# 15  SEA     1.83
# 16  MIA     1.81
# 17  SFO     1.55
# 18  FLL     1.54
# 19  PHL     1.48

# %%
df.OriginCityName.value_counts()
# Out:
# OriginCityName
# Chicago, IL              12894
# Atlanta, GA              10971
# New York, NY             10434
# Dallas/Fort Worth, TX     9479
# Denver, CO                9432
#                          ...
# Santa Maria, CA              3
# Pago Pago, TT                3
# Branson, MO                  2
# Owensboro, KY                1
# Ogden, UT                    1
# Name: count, Length: 366, dtype: int64

# %%
df.DelayGroup.value_counts()
# Out:
# DelayGroup
# OnTime_Early    143363
# Small_Delay      42673
# Medium_Delay     25647
# Large_Delay      21801
# Cancelled         6516
# Name: count, dtype: int64
